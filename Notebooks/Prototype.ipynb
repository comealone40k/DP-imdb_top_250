# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests, html
from tqdm import tqdm
import re
import json
from datetime import datetime
import logging

logging.basicConfig(format='%(levelname)s\t%(asctime)s\t%(funcName)s\t%(message)s')

# %%
def all_page_link(p_start_url: str, p_log_level:str = 'INFO') -> list:
    
    logger = logging.getLogger(__name__.ljust(30, ' '))
    logger.setLevel(p_log_level)
    
    all_urls = []
    url = p_start_url
        
    logger.info(f'Start URL: {url}')
        
    while(url != None):            #Loop around all the required webpages and terminates when last page arive!
        all_urls.append(url)
        soup = BeautifulSoup(requests.get(url).text,"html.parser")
        next_links = soup.find_all(class_='flat-button lister-page-next next-page')    #Extracts the next page link.
        if (len(next_links) == 0):         # If their is no next page, it returns 0.
            url = None
        
            logger.debug('No more pages')
                
        else:
            next_page = "https://www.imdb.com" + next_links[0].get('href')
                
            url = next_page
        
            logger.debug(f'Next page: {url}')
            
    logger.info(f'Finished, Page links are gathered for URL: {url}')
    logger.debug(f'URLs:\n{all_urls}')
                
    return all_urls

# %%
def extract_imdb_data(p_content: str, p_log_level:str = 'INFO') -> list:
    
    logger = logging.getLogger(__name__.ljust(30, ' '))
    logger.setLevel(p_log_level)
        
    logger.info('Started')
        
    logger.debug(f'Current content:\n{p_content}')
    
    soup = BeautifulSoup(p_content, 'html.parser')

    soup_data = soup.find("script", type="application/ld+json").text

    imdb_data = json.loads(soup_data)
    
    l_movie_name = html.unescape(imdb_data['name'])
        
    logger.debug(f'Data extracted from content:\n{imdb_data}')

    soup_oscars = soup.findAll("a", attrs={"class":"ipc-metadata-list-item__label ipc-metadata-list-item__label--link"})
        
    num_of_oscars = 0
    for i in soup_oscars:
        if re.search('Won(.+?)Oscars',i.text):
            num_of_oscars = int(re.findall(r'\d+',i.text)[0])

            logger.debug(f'Found Oscars: {num_of_oscars} in: {i.text}')
            
    try:
        release_date = imdb_data['datePublished']
    except KeyError as ke:
        logger.warning(f'Publish date was not found for: {l_movie_name}')
        release_date = 'N/A'
    
    l_return =  [l_movie_name,
                 release_date,
                 imdb_data['aggregateRating']['ratingValue'],
                 imdb_data['aggregateRating']['ratingCount'],
                 num_of_oscars]
        
    logger.info(f'Finished, Extracted data: {l_return}')
    
    return l_return

# %%
def extract_imdb_data(p_content: str, p_log_level: str = 'INFO') -> list:
    """
    Extracts data from IMDB page content: "name", "release_date", "rating", "votes", "oscars"
    :param p_content: str
        Content of the page to extract from ( Html response )
    :param p_log_level: str
        Log level to logging
    :return: list
        List of extracted content: "name", "release_date", "rating", "votes", "oscars"
    """

    # Initiate logging for this function, pad function name to 30 characters
    logger = logging.getLogger(__name__.ljust(30, ' '))
    logger.setLevel(p_log_level)

    logger.info('Started')

    logger.debug(f'Current content:\n{p_content}')

    soup = BeautifulSoup(p_content, 'html.parser')  # Parse page content

    soup_data = soup.find("script", type="application/ld+json").text  # Extract script data from page content

    logger.debug(f'Script data found:\n{soup_data}')

    imdb_data = json.loads(soup_data)  # Parse script data into JSON object

    # Movie names might contains html escape sequences
    # Must unescape them to get the actual name
    l_movie_name = html.unescape(imdb_data['name'])

    logger.debug(f'Data extracted from content:\n{imdb_data}')

    # Parse for data containing Awards won and Nominations info
    soup_oscars = soup.findAll("a",
                               attrs={"class": "ipc-metadata-list-item__label ipc-metadata-list-item__label--link"})

    num_of_oscars = 0  # Default Oscars won is zero
    for i in soup_oscars:  # If there is a section with relevant data, lopp through
        if re.search('Won(.+?)Oscars', i.text):  # If section contains text like 'Won X Oscars'
            num_of_oscars = int(re.findall(r'\d+', i.text)[0])  # Extract integer of Oscars won

            logger.debug(f'Found Oscars: {num_of_oscars} in: {i.text}')

    # There are some very rare cases, where date of release is not present
    # due to the movie being release before relevant info was recorded
    try:
        release_date = imdb_data['datePublished']  # Try getting datePublished field from movie data
    except KeyError as ke:  # in case there is no such field
        logger.warning(f'Publish date was not found for: {l_movie_name}')  # Log a warning and set release date as "N/A"
        release_date = 'N/A'

    l_return = [l_movie_name,
                release_date,
                imdb_data['aggregateRating']['ratingValue'],
                imdb_data['aggregateRating']['ratingCount'],
                num_of_oscars]

    logger.info(f'Finished, Extracted data: {l_return}')

    return l_return

# %%
def extract_imdb_top_250_data(p_log_level:str = 'INFO') -> pd.DataFrame:
    
    logger = logging.getLogger(__name__.ljust(30, ' '))
    logger.setLevel(p_log_level)
        
    logger.info('Started')
    
    l_top_250_url = "https://www.imdb.com/list/ls068082370/"
        
    logger.debug(f'Starting on URL: {l_top_250_url}')
        
    t = tqdm(all_page_link(p_start_url=l_top_250_url, p_log_level=p_log_level))
    
    links_set = set()
    for i in t:
        soup = BeautifulSoup(requests.get(i).text,"html.parser")
        links = [a['href'] for a in soup.select('a[href]')]
        current_link_set = set(list(filter(lambda link: 'title/tt' in link, links)))
        
        logger.debug(f'Adding links:\n{current_link_set}')
        
        links_set = links_set.union(current_link_set)
        
    logger.debug(f'Current set of links:\n{links}')
        
    imdb_top_250_data = []
    for link in links_set:
        l_current_link = f'https://www.imdb.com{link}'
        
        logger.debug(f'Extracting data from URL:{l_current_link}')
            
        l_content = requests.get(l_current_link).content
        imdb_top_250_data.append(extract_imdb_data(p_content=l_content, p_log_level=p_log_level))
        
    index = ["name", "release_date", "rating", "votes", "oscars"]

    df = pd.DataFrame(imdb_top_250_data,columns=index)
        
    logger.info(f'Finished, Result dataframe:\n{df}')
    
    return df

# %%
def oscars_adjustment(p_num_of_oscars: int) -> float:
    if p_num_of_oscars == 0:
        return 0
    elif p_num_of_oscars > 0 and p_num_of_oscars < 3:
        return 0.3
    elif p_num_of_oscars > 2 and p_num_of_oscars < 6:
        return 0.5
    elif p_num_of_oscars > 5 and p_num_of_oscars < 11:
        return 1
    else:
        return 1.5

# %%
def write_imdb_data_to_csv(p_df:pd.DataFrame, 
                           p_file:str, 
                           p_sep:str = ';', 
                           p_overwrite:bool = False, 
                           p_log_level:str = 'INFO'):
    
    logger = logging.getLogger(__name__.ljust(30, ' '))
    logger.setLevel(p_log_level)
        
    logger.info(f'Started writing file: {p_file}')
    
    p_df.to_csv(path_or_buf=p_file, sep=p_sep, index=True, header=True, index_label='rank')
        
    logger.info(f'Finished writing file: {p_file}')

# %%
df = extract_imdb_top_250_data(p_log_level='INFO')
# Out:
# INFO	2022-10-23 14:42:56,566	extract_imdb_top_250_data	Started
# INFO	2022-10-23 14:42:56,573	all_page_link	Start URL: https://www.imdb.com/list/ls068082370/
# INFO	2022-10-23 14:43:09,711	all_page_link	Finished, Page links are gathered for URL: None
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:13<00:00,  4.37s/it]
# INFO	2022-10-23 14:43:23,864	extract_imdb_data	Started
# INFO	2022-10-23 14:43:23,997	extract_imdb_data	Finished, Extracted data: ['Se7en', '1996-11-07', 8.6, 1633996, 0]
# INFO	2022-10-23 14:43:24,909	extract_imdb_data	Started
# INFO	2022-10-23 14:43:25,037	extract_imdb_data	Finished, Extracted data: ['Indiana Jones and the Temple of Doom', '1986-07-31', 7.5, 486587, 0]
# INFO	2022-10-23 14:43:25,941	extract_imdb_data	Started
# INFO	2022-10-23 14:43:26,078	extract_imdb_data	Finished, Extracted data: ['El secreto de sus ojos', '2010-10-21', 8.2, 209572, 0]
# INFO	2022-10-23 14:43:26,989	extract_imdb_data	Started
# INFO	2022-10-23 14:43:27,121	extract_imdb_data	Finished, Extracted data: ['Into the Wild', '2008-04-03', 8.1, 621367, 0]
# INFO	2022-10-23 14:43:28,062	extract_imdb_data	Started
# INFO	2022-10-23 14:43:28,499	extract_imdb_data	Finished, Extracted data: ['The Dark Knight Rises', '2012-07-26', 8.4, 1690541, 0]
# INFO	2022-10-23 14:43:29,398	extract_imdb_data	Started
# INFO	2022-10-23 14:43:29,534	extract_imdb_data	Finished, Extracted data: ['Rear Window', '1986-08-07', 8.5, 489568, 0]
# INFO	2022-10-23 14:43:30,529	extract_imdb_data	Started
# INFO	2022-10-23 14:43:30,869	extract_imdb_data	Finished, Extracted data: ['Planet of the Apes', '1981-08-06', 8, 180499, 0]
# INFO	2022-10-23 14:43:31,947	extract_imdb_data	Started
# INFO	2022-10-23 14:43:32,082	extract_imdb_data	Finished, Extracted data: ['Raiders of the Lost Ark', '1985-10-24', 8.4, 960066, 4]
# INFO	2022-10-23 14:43:33,202	extract_imdb_data	Started
# INFO	2022-10-23 14:43:33,327	extract_imdb_data	Finished, Extracted data: ['The Big Lebowski', '1998-09-24', 8.1, 804411, 0]
# INFO	2022-10-23 14:43:34,371	extract_imdb_data	Started
# INFO	2022-10-23 14:43:34,515	extract_imdb_data	Finished, Extracted data: ['Up', '2009-10-15', 8.3, 1036511, 2]
# INFO	2022-10-23 14:43:35,441	extract_imdb_data	Started
# INFO	2022-10-23 14:43:35,550	extract_imdb_data	Finished, Extracted data: ['Network', '1980-09-11', 8.1, 159792, 4]
# INFO	2022-10-23 14:43:36,468	extract_imdb_data	Started
# INFO	2022-10-23 14:43:36,611	extract_imdb_data	Finished, Extracted data: ['The Pianist', '2003-03-20', 8.5, 824648, 3]
# INFO	2022-10-23 14:43:37,808	extract_imdb_data	Started
# INFO	2022-10-23 14:43:38,422	extract_imdb_data	Finished, Extracted data: ['Reservoir Dogs', '1992-09-02', 8.3, 1010583, 0]
# INFO	2022-10-23 14:43:39,392	extract_imdb_data	Started
# INFO	2022-10-23 14:43:39,521	extract_imdb_data	Finished, Extracted data: ['It Happened One Night', '1935-01-10', 8.1, 104133, 5]
# INFO	2022-10-23 14:43:40,541	extract_imdb_data	Started
# INFO	2022-10-23 14:43:40,669	extract_imdb_data	Finished, Extracted data: ['The Empire Strikes Back', '1982-01-28', 8.7, 1281807, 0]
# INFO	2022-10-23 14:43:42,346	extract_imdb_data	Started
# INFO	2022-10-23 14:43:42,473	extract_imdb_data	Finished, Extracted data: ['The Usual Suspects', '1996-06-13', 8.5, 1078530, 2]
# INFO	2022-10-23 14:43:43,543	extract_imdb_data	Started
# INFO	2022-10-23 14:43:43,670	extract_imdb_data	Finished, Extracted data: ['Mononoke-hime', '1997-07-12', 8.4, 392241, 0]
# INFO	2022-10-23 14:43:44,573	extract_imdb_data	Started
# INFO	2022-10-23 14:43:44,835	extract_imdb_data	Finished, Extracted data: ['Shichinin no samurai', '1954-04-26', 8.6, 344744, 0]
# INFO	2022-10-23 14:43:45,775	extract_imdb_data	Started
# INFO	2022-10-23 14:43:45,905	extract_imdb_data	Finished, Extracted data: ['Rang De Basanti', '2006-01-26', 8.1, 119223, 0]
# INFO	2022-10-23 14:43:46,557	extract_imdb_data	Started
# INFO	2022-10-23 14:43:46,675	extract_imdb_data	Finished, Extracted data: ['Hauru no ugoku shiro', '2005-12-15', 8.2, 392443, 0]
# INFO	2022-10-23 14:43:48,357	extract_imdb_data	Started
# INFO	2022-10-23 14:43:48,495	extract_imdb_data	Finished, Extracted data: ['The Lord of the Rings: The Two Towers', '2003-01-09', 8.8, 1651289, 2]
# INFO	2022-10-23 14:43:49,458	extract_imdb_data	Started
# INFO	2022-10-23 14:43:49,574	extract_imdb_data	Finished, Extracted data: ['Finding Nemo', '2003-11-20', 8.2, 1037300, 0]
# INFO	2022-10-23 14:43:50,596	extract_imdb_data	Started
# INFO	2022-10-23 14:43:50,844	extract_imdb_data	Finished, Extracted data: ['The Third Man', '1949-09-03', 8.1, 171831, 0]
# INFO	2022-10-23 14:43:51,751	extract_imdb_data	Started
# INFO	2022-10-23 14:43:51,884	extract_imdb_data	Finished, Extracted data: ["Singin' in the Rain", '1964-07-16', 8.3, 241898, 0]
# INFO	2022-10-23 14:43:53,114	extract_imdb_data	Started
# INFO	2022-10-23 14:43:53,243	extract_imdb_data	Finished, Extracted data: ['Sen to Chihiro no kamikakushi', '2003-03-06', 8.6, 754846, 0]
# INFO	2022-10-23 14:43:54,361	extract_imdb_data	Started
# INFO	2022-10-23 14:43:54,494	extract_imdb_data	Finished, Extracted data: ['Rebecca', '1941-02-13', 8.1, 137417, 2]
# INFO	2022-10-23 14:43:55,595	extract_imdb_data	Started
# INFO	2022-10-23 14:43:55,730	extract_imdb_data	Finished, Extracted data: ['The Wizard of Oz', '1940-03-21', 8.1, 398431, 2]
# INFO	2022-10-23 14:43:56,841	extract_imdb_data	Started
# INFO	2022-10-23 14:43:57,135	extract_imdb_data	Finished, Extracted data: ["Ocean's Eleven", '2002-02-21', 7.7, 571875, 0]
# INFO	2022-10-23 14:43:58,045	extract_imdb_data	Started
# INFO	2022-10-23 14:43:58,281	extract_imdb_data	Finished, Extracted data: ['Nuovo Cinema Paradiso', '1990-05-17', 8.5, 260131, 0]
# INFO	2022-10-23 14:43:59,396	extract_imdb_data	Started
# INFO	2022-10-23 14:43:59,527	extract_imdb_data	Finished, Extracted data: ['How to Train Your Dragon', '2010-03-25', 8.1, 735833, 0]
# INFO	2022-10-23 14:44:00,619	extract_imdb_data	Started
# INFO	2022-10-23 14:44:00,744	extract_imdb_data	Finished, Extracted data: ['Django Unchained', '2013-01-17', 8.4, 1536308, 2]
# INFO	2022-10-23 14:44:01,680	extract_imdb_data	Started
# INFO	2022-10-23 14:44:01,812	extract_imdb_data	Finished, Extracted data: ['Vertigo', '1985-12-19', 8.3, 401157, 0]
# INFO	2022-10-23 14:44:02,521	extract_imdb_data	Started
# INFO	2022-10-23 14:44:02,637	extract_imdb_data	Finished, Extracted data: ['The Elephant Man', '1985-12-19', 8.2, 240957, 0]
# INFO	2022-10-23 14:44:03,368	extract_imdb_data	Started
# INFO	2022-10-23 14:44:03,642	extract_imdb_data	Finished, Extracted data: ['On the Waterfront', '1954-06-22', 8.1, 155312, 8]
# INFO	2022-10-23 14:44:04,720	extract_imdb_data	Started
# INFO	2022-10-23 14:44:04,844	extract_imdb_data	Finished, Extracted data: ['The Departed', '2006-11-09', 8.5, 1314423, 4]
# INFO	2022-10-23 14:44:05,962	extract_imdb_data	Started
# INFO	2022-10-23 14:44:06,096	extract_imdb_data	Finished, Extracted data: ['WALL·E', '2008-07-24', 8.4, 1107680, 0]
# INFO	2022-10-23 14:44:07,554	extract_imdb_data	Started
# INFO	2022-10-23 14:44:07,691	extract_imdb_data	Finished, Extracted data: ['Eternal Sunshine of the Spotless Mind', '2004-08-19', 8.3, 1000523, 0]
# INFO	2022-10-23 14:44:08,749	extract_imdb_data	Started
# INFO	2022-10-23 14:44:08,869	extract_imdb_data	Finished, Extracted data: ['American Beauty', '2000-02-17', 8.4, 1148897, 5]
# INFO	2022-10-23 14:44:09,756	extract_imdb_data	Started
# INFO	2022-10-23 14:44:09,877	extract_imdb_data	Finished, Extracted data: ['Catch Me If You Can', '2003-02-06', 8.1, 970795, 0]
# INFO	2022-10-23 14:44:10,825	extract_imdb_data	Started
# INFO	2022-10-23 14:44:11,084	extract_imdb_data	Finished, Extracted data: ['Donnie Darko', '2003-05-22', 8, 797696, 0]
# INFO	2022-10-23 14:44:12,004	extract_imdb_data	Started
# INFO	2022-10-23 14:44:12,140	extract_imdb_data	Finished, Extracted data: ['Guardians of the Galaxy Vol. 2', '2017-05-04', 7.6, 674513, 0]
# INFO	2022-10-23 14:44:13,203	extract_imdb_data	Started
# INFO	2022-10-23 14:44:13,321	extract_imdb_data	Finished, Extracted data: ['X-Men', '2000-11-02', 7.3, 614612, 0]
# INFO	2022-10-23 14:44:14,310	extract_imdb_data	Started
# INFO	2022-10-23 14:44:14,433	extract_imdb_data	Finished, Extracted data: ['Cool Hand Luke', '1968-10-10', 8.1, 177415, 0]
# INFO	2022-10-23 14:44:15,231	extract_imdb_data	Started
# INFO	2022-10-23 14:44:15,360	extract_imdb_data	Finished, Extracted data: ['Sunset Blvd.', '1950-08-04', 8.4, 221627, 3]
# INFO	2022-10-23 14:44:16,209	extract_imdb_data	Started
# INFO	2022-10-23 14:44:16,883	extract_imdb_data	Finished, Extracted data: ['The Godfather', '1982-03-25', 9.2, 1839009, 3]
# INFO	2022-10-23 14:44:17,826	extract_imdb_data	Started
# INFO	2022-10-23 14:44:17,953	extract_imdb_data	Finished, Extracted data: ['Some Like It Hot', '1965-08-05', 8.2, 266904, 0]
# INFO	2022-10-23 14:44:18,930	extract_imdb_data	Started
# INFO	2022-10-23 14:44:19,054	extract_imdb_data	Finished, Extracted data: ['Kill Bill: Vol. 1', '2003-10-16', 8.2, 1107239, 0]
# INFO	2022-10-23 14:44:20,167	extract_imdb_data	Started
# INFO	2022-10-23 14:44:20,276	extract_imdb_data	Finished, Extracted data: ['Annie Hall', '1980-05-22', 8, 265706, 4]
# INFO	2022-10-23 14:44:21,188	extract_imdb_data	Started
# INFO	2022-10-23 14:44:21,307	extract_imdb_data	Finished, Extracted data: ['Tonari no Totoro', '1988-04-16', 8.1, 337187, 0]
# INFO	2022-10-23 14:44:22,286	extract_imdb_data	Started
# INFO	2022-10-23 14:44:22,558	extract_imdb_data	Finished, Extracted data: ['La vita è bella', '1999-04-08', 8.6, 690037, 3]
# INFO	2022-10-23 14:44:23,635	extract_imdb_data	Started
# INFO	2022-10-23 14:44:23,763	extract_imdb_data	Finished, Extracted data: ['Lawrence of Arabia', '1962-12-11', 8.3, 293189, 7]
# INFO	2022-10-23 14:44:24,794	extract_imdb_data	Started
# INFO	2022-10-23 14:44:24,919	extract_imdb_data	Finished, Extracted data: ['The Deer Hunter', '1990-03-01', 8.1, 338803, 5]
# INFO	2022-10-23 14:44:25,781	extract_imdb_data	Started
# INFO	2022-10-23 14:44:26,278	extract_imdb_data	Finished, Extracted data: ['Ladri di biciclette', '1950-04-30', 8.3, 163522, 0]
# INFO	2022-10-23 14:44:27,199	extract_imdb_data	Started
# INFO	2022-10-23 14:44:27,340	extract_imdb_data	Finished, Extracted data: ['Witness for the Prosecution', '1962-01-22', 8.4, 125322, 0]
# INFO	2022-10-23 14:44:28,286	extract_imdb_data	Started
# INFO	2022-10-23 14:44:28,410	extract_imdb_data	Finished, Extracted data: ['Citizen Kane', '1947-07-28', 8.3, 440951, 0]
# INFO	2022-10-23 14:44:29,745	extract_imdb_data	Started
# INFO	2022-10-23 14:44:30,006	extract_imdb_data	Finished, Extracted data: ['Young Frankenstein', '1987-07-16', 8, 158490, 0]
# INFO	2022-10-23 14:44:30,940	extract_imdb_data	Started
# INFO	2022-10-23 14:44:31,060	extract_imdb_data	Finished, Extracted data: ['Gran Torino', '2009-04-16', 8.1, 773021, 0]
# INFO	2022-10-23 14:44:31,875	extract_imdb_data	Started
# INFO	2022-10-23 14:44:31,990	extract_imdb_data	Finished, Extracted data: ["Hachi: A Dog's Tale", '2010-03-12', 8.1, 284217, 0]
# INFO	2022-10-23 14:44:32,933	extract_imdb_data	Started
# INFO	2022-10-23 14:44:33,058	extract_imdb_data	Finished, Extracted data: ['Fight Club', '2000-01-27', 8.8, 2098207, 0]
# INFO	2022-10-23 14:44:34,566	extract_imdb_data	Started
# INFO	2022-10-23 14:44:34,679	extract_imdb_data	Finished, Extracted data: ['Batman Begins', '2005-07-14', 8.2, 1458813, 0]
# INFO	2022-10-23 14:44:35,732	extract_imdb_data	Started
# INFO	2022-10-23 14:44:36,269	extract_imdb_data	Finished, Extracted data: ['Shutter Island', '2010-03-04', 8.2, 1297543, 0]
# INFO	2022-10-23 14:44:37,255	extract_imdb_data	Started
# INFO	2022-10-23 14:44:37,394	extract_imdb_data	Finished, Extracted data: ['Requiem for a Dream', '2001-02-22', 8.3, 836964, 0]
# INFO	2022-10-23 14:44:38,615	extract_imdb_data	Started
# INFO	2022-10-23 14:44:38,747	extract_imdb_data	Finished, Extracted data: ['Toy Story 3', '2010-06-17', 8.3, 831311, 2]
# INFO	2022-10-23 14:44:39,862	extract_imdb_data	Started
# INFO	2022-10-23 14:44:39,982	extract_imdb_data	Finished, Extracted data: ['Paths of Glory', '1957-12-25', 8.4, 197137, 0]
# INFO	2022-10-23 14:44:40,924	extract_imdb_data	Started
# INFO	2022-10-23 14:44:41,061	extract_imdb_data	Finished, Extracted data: ['Quantum of Solace', '2008-11-13', 6.6, 448391, 0]
# INFO	2022-10-23 14:44:42,236	extract_imdb_data	Started
# WARNING	2022-10-23 14:44:42,369	extract_imdb_data	Publish date was not found for: Bacheha-Ye aseman
# INFO	2022-10-23 14:44:42,370	extract_imdb_data	Finished, Extracted data: ['Bacheha-Ye aseman', 'N/A', 8.2, 74975, 0]
# INFO	2022-10-23 14:44:43,508	extract_imdb_data	Started
# INFO	2022-10-23 14:44:43,777	extract_imdb_data	Finished, Extracted data: ['Ran', '1992-08-28', 8.2, 125748, 0]
# INFO	2022-10-23 14:44:44,858	extract_imdb_data	Started
# INFO	2022-10-23 14:44:45,367	extract_imdb_data	Finished, Extracted data: ['Back to the Future', '1987-10-15', 8.5, 1192301, 0]
# INFO	2022-10-23 14:44:46,360	extract_imdb_data	Started
# INFO	2022-10-23 14:44:46,484	extract_imdb_data	Finished, Extracted data: ['Gone Girl', '2014-10-02', 8.1, 974872, 0]
# INFO	2022-10-23 14:44:47,295	extract_imdb_data	Started
# INFO	2022-10-23 14:44:47,435	extract_imdb_data	Finished, Extracted data: ['Stand by Me', '1986-08-22', 8.1, 402408, 0]
# INFO	2022-10-23 14:44:48,368	extract_imdb_data	Started
# INFO	2022-10-23 14:44:48,474	extract_imdb_data	Finished, Extracted data: ['Life of Brian', '1979-11-08', 8, 399049, 0]
# INFO	2022-10-23 14:44:49,686	extract_imdb_data	Started
# INFO	2022-10-23 14:44:49,926	extract_imdb_data	Finished, Extracted data: ['Sunrise: A Song of Two Humans', '1928-01-05', 8.1, 51232, 3]
# INFO	2022-10-23 14:44:50,987	extract_imdb_data	Started
# INFO	2022-10-23 14:44:51,105	extract_imdb_data	Finished, Extracted data: ['Ben-Hur', '1982-08-26', 8.1, 239279, 11]
# INFO	2022-10-23 14:44:52,100	extract_imdb_data	Started
# INFO	2022-10-23 14:44:52,219	extract_imdb_data	Finished, Extracted data: ['Stalker', '1980-10-23', 8.1, 134150, 0]
# INFO	2022-10-23 14:44:53,456	extract_imdb_data	Started
# INFO	2022-10-23 14:44:53,590	extract_imdb_data	Finished, Extracted data: ["One Flew Over the Cuckoo's Nest", '1977-05-19', 8.7, 1001435, 5]
# INFO	2022-10-23 14:44:54,669	extract_imdb_data	Started
# INFO	2022-10-23 14:44:55,019	extract_imdb_data	Finished, Extracted data: ['The Shawshank Redemption', '1995-05-25', 9.3, 2652964, 0]
# INFO	2022-10-23 14:44:56,472	extract_imdb_data	Started
# INFO	2022-10-23 14:44:56,586	extract_imdb_data	Finished, Extracted data: ['Oldeuboi', '2005-02-10', 8.4, 575353, 0]
# INFO	2022-10-23 14:44:57,464	extract_imdb_data	Started
# INFO	2022-10-23 14:44:57,718	extract_imdb_data	Finished, Extracted data: ['L.A. Confidential', '1998-01-29', 8.2, 581321, 2]
# INFO	2022-10-23 14:44:58,942	extract_imdb_data	Started
# INFO	2022-10-23 14:44:59,072	extract_imdb_data	Finished, Extracted data: ['Forrest Gump', '1994-12-08', 8.8, 2055018, 6]
# INFO	2022-10-23 14:45:00,163	extract_imdb_data	Started
# INFO	2022-10-23 14:45:00,287	extract_imdb_data	Finished, Extracted data: ['The Sixth Sense', '2000-01-06', 8.2, 986582, 0]
# INFO	2022-10-23 14:45:01,442	extract_imdb_data	Started
# INFO	2022-10-23 14:45:01,555	extract_imdb_data	Finished, Extracted data: ['12 Years a Slave', '2014-01-02', 8.1, 697948, 3]
# INFO	2022-10-23 14:45:02,422	extract_imdb_data	Started
# INFO	2022-10-23 14:45:02,540	extract_imdb_data	Finished, Extracted data: ['Il buono, il brutto, il cattivo', '1979-11-29', 8.8, 756783, 0]
# INFO	2022-10-23 14:45:03,662	extract_imdb_data	Started
# INFO	2022-10-23 14:45:03,943	extract_imdb_data	Finished, Extracted data: ['Per qualche dollaro in più', '1965-12-20', 8.2, 256345, 0]
# INFO	2022-10-23 14:45:05,242	extract_imdb_data	Started
# INFO	2022-10-23 14:45:05,362	extract_imdb_data	Finished, Extracted data: ['Andaz Apna Apna', '1994-11-04', 8, 53514, 0]
# INFO	2022-10-23 14:45:06,249	extract_imdb_data	Started
# INFO	2022-10-23 14:45:06,377	extract_imdb_data	Finished, Extracted data: ['Hotel Rwanda', '2005-09-29', 8.1, 355432, 0]
# INFO	2022-10-23 14:45:07,639	extract_imdb_data	Started
# INFO	2022-10-23 14:45:07,744	extract_imdb_data	Finished, Extracted data: ['La haine', '1996-01-18', 8.1, 173332, 0]
# INFO	2022-10-23 14:45:08,729	extract_imdb_data	Started
# INFO	2022-10-23 14:45:08,861	extract_imdb_data	Finished, Extracted data: ['Star Wars', '1979-08-16', 8.6, 1354465, 6]
# INFO	2022-10-23 14:45:09,892	extract_imdb_data	Started
# INFO	2022-10-23 14:45:10,169	extract_imdb_data	Finished, Extracted data: ['Shrek', '2001-06-21', 7.9, 673047, 0]
# INFO	2022-10-23 14:45:11,367	extract_imdb_data	Started
# INFO	2022-10-23 14:45:11,483	extract_imdb_data	Finished, Extracted data: ['The Kid', '1924-08-22', 8.3, 126549, 0]
# INFO	2022-10-23 14:45:12,441	extract_imdb_data	Started
# INFO	2022-10-23 14:45:12,547	extract_imdb_data	Finished, Extracted data: ['Das Boot', '1990-06-07', 8.4, 250839, 0]
# INFO	2022-10-23 14:45:13,472	extract_imdb_data	Started
# INFO	2022-10-23 14:45:13,791	extract_imdb_data	Finished, Extracted data: ['Once Upon a Time in America', '1989-03-30', 8.3, 350819, 0]
# INFO	2022-10-23 14:45:14,762	extract_imdb_data	Started
# INFO	2022-10-23 14:45:14,881	extract_imdb_data	Finished, Extracted data: ['Good Will Hunting', '1999-02-25', 8.3, 959367, 2]
# INFO	2022-10-23 14:45:15,842	extract_imdb_data	Started
# INFO	2022-10-23 14:45:15,957	extract_imdb_data	Finished, Extracted data: ['Gangs of Wasseypur', '2012-06-22', 8.2, 96215, 0]
# INFO	2022-10-23 14:45:16,819	extract_imdb_data	Started
# INFO	2022-10-23 14:45:17,064	extract_imdb_data	Finished, Extracted data: ['Scarface', '1983-12-09', 8.3, 833866, 0]
# INFO	2022-10-23 14:45:17,902	extract_imdb_data	Started
# INFO	2022-10-23 14:45:18,023	extract_imdb_data	Finished, Extracted data: ['3 Idiots', '2009-12-25', 8.4, 398133, 0]
# INFO	2022-10-23 14:45:18,963	extract_imdb_data	Started
# INFO	2022-10-23 14:45:19,082	extract_imdb_data	Finished, Extracted data: ['Casablanca', '1947-01-30', 8.5, 568984, 3]
# INFO	2022-10-23 14:45:20,057	extract_imdb_data	Started
# INFO	2022-10-23 14:45:20,180	extract_imdb_data	Finished, Extracted data: ['Modern Times', '1936-10-07', 8.5, 241852, 0]
# INFO	2022-10-23 14:45:21,142	extract_imdb_data	Started
# INFO	2022-10-23 14:45:21,265	extract_imdb_data	Finished, Extracted data: ['Chinatown', '1979-09-27', 8.2, 326029, 0]
# INFO	2022-10-23 14:45:22,105	extract_imdb_data	Started
# INFO	2022-10-23 14:45:22,357	extract_imdb_data	Finished, Extracted data: ['Idi i smotri', '1985-10-17', 8.4, 79143, 0]
# INFO	2022-10-23 14:45:23,570	extract_imdb_data	Started
# INFO	2022-10-23 14:45:23,875	extract_imdb_data	Finished, Extracted data: ['In the Name of the Father', '1994-04-07', 8.1, 175051, 0]
# INFO	2022-10-23 14:45:25,098	extract_imdb_data	Started
# INFO	2022-10-23 14:45:25,218	extract_imdb_data	Finished, Extracted data: ['Det sjunde inseglet', '1957-02-16', 8.1, 185190, 0]
# INFO	2022-10-23 14:45:25,967	extract_imdb_data	Started
# INFO	2022-10-23 14:45:26,096	extract_imdb_data	Finished, Extracted data: ['Dial M for Murder', '1954-05-29', 8.2, 175887, 0]
# INFO	2022-10-23 14:45:27,041	extract_imdb_data	Started
# INFO	2022-10-23 14:45:27,165	extract_imdb_data	Finished, Extracted data: ['Drishyam', '2015-07-31', 8.2, 82066, 0]
# INFO	2022-10-23 14:45:28,238	extract_imdb_data	Started
# INFO	2022-10-23 14:45:28,356	extract_imdb_data	Finished, Extracted data: ['V for Vendetta', '2006-04-20', 8.2, 1115967, 0]
# INFO	2022-10-23 14:45:29,415	extract_imdb_data	Started
# INFO	2022-10-23 14:45:29,687	extract_imdb_data	Finished, Extracted data: ['American Psycho', '2000-04-14', 7.6, 604989, 0]
# INFO	2022-10-23 14:45:30,744	extract_imdb_data	Started
# INFO	2022-10-23 14:45:30,890	extract_imdb_data	Finished, Extracted data: ['The Great Escape', '1963-07-04', 8.2, 244386, 0]
# INFO	2022-10-23 14:45:32,467	extract_imdb_data	Started
# INFO	2022-10-23 14:45:32,588	extract_imdb_data	Finished, Extracted data: ['Jurassic Park', '1993-09-24', 8.2, 981689, 3]
# INFO	2022-10-23 14:45:33,748	extract_imdb_data	Started
# INFO	2022-10-23 14:45:34,057	extract_imdb_data	Finished, Extracted data: ['The Lord of the Rings: The Fellowship of the Ring', '2002-01-10', 8.8, 1856453, 4]
# INFO	2022-10-23 14:45:35,026	extract_imdb_data	Started
# INFO	2022-10-23 14:45:35,148	extract_imdb_data	Finished, Extracted data: ['Inglourious Basterds', '2009-08-20', 8.3, 1432940, 0]
# INFO	2022-10-23 14:45:36,168	extract_imdb_data	Started
# INFO	2022-10-23 14:45:36,435	extract_imdb_data	Finished, Extracted data: ['Room', '2016-01-28', 8.1, 418987, 0]
# INFO	2022-10-23 14:45:37,801	extract_imdb_data	Started
# INFO	2022-10-23 14:45:37,943	extract_imdb_data	Finished, Extracted data: ['The Princess Bride', '1990-03-15', 8, 426620, 0]
# INFO	2022-10-23 14:45:38,889	extract_imdb_data	Started
# INFO	2022-10-23 14:45:39,003	extract_imdb_data	Finished, Extracted data: ['Mr. Smith Goes to Washington', '1941-09-24', 8.1, 115875, 0]
# INFO	2022-10-23 14:45:40,558	extract_imdb_data	Started
# INFO	2022-10-23 14:45:40,696	extract_imdb_data	Finished, Extracted data: ['Million Dollar Baby', '2005-03-10', 8.1, 685344, 4]
# INFO	2022-10-23 14:45:41,633	extract_imdb_data	Started
# INFO	2022-10-23 14:45:41,751	extract_imdb_data	Finished, Extracted data: ['Der Untergang', '2005-01-20', 8.2, 355277, 0]
# INFO	2022-10-23 14:45:43,241	extract_imdb_data	Started
# INFO	2022-10-23 14:45:43,733	extract_imdb_data	Finished, Extracted data: ['Heat', '1996-04-04', 8.3, 651118, 0]
# INFO	2022-10-23 14:45:44,766	extract_imdb_data	Started
# INFO	2022-10-23 14:45:45,015	extract_imdb_data	Finished, Extracted data: ["La passion de Jeanne d'Arc", '1928-10-25', 8.2, 55012, 0]
# INFO	2022-10-23 14:45:46,287	extract_imdb_data	Started
# INFO	2022-10-23 14:45:46,415	extract_imdb_data	Finished, Extracted data: ['Cidade de Deus', '2003-03-13', 8.6, 752790, 0]
# INFO	2022-10-23 14:45:47,353	extract_imdb_data	Started
# INFO	2022-10-23 14:45:47,487	extract_imdb_data	Finished, Extracted data: ['Judgment at Nuremberg', '1966-01-27', 8.3, 77840, 2]
# INFO	2022-10-23 14:45:48,552	extract_imdb_data	Started
# INFO	2022-10-23 14:45:48,691	extract_imdb_data	Finished, Extracted data: ['Inception', '2010-07-22', 8.8, 2326728, 4]
# INFO	2022-10-23 14:45:49,686	extract_imdb_data	Started
# INFO	2022-10-23 14:45:49,791	extract_imdb_data	Finished, Extracted data: ['The Silence of the Lambs', '1992-03-27', 8.6, 1418756, 5]
# INFO	2022-10-23 14:45:50,849	extract_imdb_data	Started
# INFO	2022-10-23 14:45:51,108	extract_imdb_data	Finished, Extracted data: ['Gandhi', '1984-09-27', 8.1, 231667, 8]
# INFO	2022-10-23 14:45:52,016	extract_imdb_data	Started
# INFO	2022-10-23 14:45:52,130	extract_imdb_data	Finished, Extracted data: ['Apocalypse Now', '1980-04-24', 8.5, 663761, 2]
# INFO	2022-10-23 14:45:53,100	extract_imdb_data	Started
# INFO	2022-10-23 14:45:53,410	extract_imdb_data	Finished, Extracted data: ['Blade Runner', '1988-06-23', 8.1, 764944, 0]
# INFO	2022-10-23 14:45:54,508	extract_imdb_data	Started
# INFO	2022-10-23 14:45:54,632	extract_imdb_data	Finished, Extracted data: ['Fargo', '1997-02-27', 8.1, 675218, 2]
# INFO	2022-10-23 14:45:55,579	extract_imdb_data	Started
# INFO	2022-10-23 14:45:55,702	extract_imdb_data	Finished, Extracted data: ['Eskiya', '1996-11-29', 8.1, 70136, 0]
# INFO	2022-10-23 14:45:57,114	extract_imdb_data	Started
# INFO	2022-10-23 14:45:57,243	extract_imdb_data	Finished, Extracted data: ['Memento', '2001-05-17', 8.4, 1229729, 0]
# INFO	2022-10-23 14:45:58,223	extract_imdb_data	Started
# INFO	2022-10-23 14:45:58,492	extract_imdb_data	Finished, Extracted data: ['The Great Dictator', '1947-12-19', 8.4, 223625, 0]
# INFO	2022-10-23 14:45:59,408	extract_imdb_data	Started
# INFO	2022-10-23 14:45:59,529	extract_imdb_data	Finished, Extracted data: ['Fa yeung nin wah', '2001-03-29', 8.1, 149538, 0]
# INFO	2022-10-23 14:46:00,742	extract_imdb_data	Started
# INFO	2022-10-23 14:46:00,859	extract_imdb_data	Finished, Extracted data: ['Star Wars: Episode VI - Return of the Jedi', '1984-09-13', 8.3, 1046504, 0]
# INFO	2022-10-23 14:46:01,935	extract_imdb_data	Started
# INFO	2022-10-23 14:46:02,359	extract_imdb_data	Finished, Extracted data: ["Schindler's List", '1994-03-10', 9, 1344273, 7]
# INFO	2022-10-23 14:46:03,553	extract_imdb_data	Started
# INFO	2022-10-23 14:46:03,676	extract_imdb_data	Finished, Extracted data: ['Ikiru', '1952-10-09', 8.3, 78541, 0]
# INFO	2022-10-23 14:46:04,752	extract_imdb_data	Started
# INFO	2022-10-23 14:46:04,986	extract_imdb_data	Finished, Extracted data: ['Double Indemnity', '1947-05-29', 8.3, 157368, 0]
# INFO	2022-10-23 14:46:06,312	extract_imdb_data	Started
# INFO	2022-10-23 14:46:06,429	extract_imdb_data	Finished, Extracted data: ['Mary and Max.', '2010-09-30', 8.1, 177346, 0]
# INFO	2022-10-23 14:46:07,337	extract_imdb_data	Started
# INFO	2022-10-23 14:46:07,465	extract_imdb_data	Finished, Extracted data: ['Raging Bull', '1984-02-09', 8.2, 353127, 2]
# INFO	2022-10-23 14:46:08,509	extract_imdb_data	Started
# INFO	2022-10-23 14:46:08,631	extract_imdb_data	Finished, Extracted data: ['Braveheart', '1995-10-26', 8.4, 1032634, 5]
# INFO	2022-10-23 14:46:10,049	extract_imdb_data	Started
# INFO	2022-10-23 14:46:10,164	extract_imdb_data	Finished, Extracted data: ['Persona', '1966-10-18', 8.1, 118768, 0]
# INFO	2022-10-23 14:46:11,091	extract_imdb_data	Started
# INFO	2022-10-23 14:46:11,221	extract_imdb_data	Finished, Extracted data: ['Monsters, Inc.', '2002-02-14', 8.1, 903068, 0]
# INFO	2022-10-23 14:46:12,141	extract_imdb_data	Started
# INFO	2022-10-23 14:46:12,781	extract_imdb_data	Finished, Extracted data: ['Mou gaan dou', '2004-01-29', 8, 125008, 0]
# INFO	2022-10-23 14:46:13,670	extract_imdb_data	Started
# INFO	2022-10-23 14:46:13,801	extract_imdb_data	Finished, Extracted data: ['The Maltese Falcon', '1941-10-18', 8, 158889, 0]
# INFO	2022-10-23 14:46:15,254	extract_imdb_data	Started
# INFO	2022-10-23 14:46:15,381	extract_imdb_data	Finished, Extracted data: ["Le fabuleux destin d'Amélie Poulain", '2002-02-21', 8.3, 753735, 0]
# INFO	2022-10-23 14:46:16,391	extract_imdb_data	Started
# INFO	2022-10-23 14:46:16,508	extract_imdb_data	Finished, Extracted data: ['Intouchables', '2011-12-22', 8.5, 850590, 0]
# INFO	2022-10-23 14:46:17,650	extract_imdb_data	Started
# INFO	2022-10-23 14:46:17,768	extract_imdb_data	Finished, Extracted data: ['Andrey Rublyov', '1973-04-05', 8.1, 53818, 0]
# INFO	2022-10-23 14:46:18,668	extract_imdb_data	Started
# INFO	2022-10-23 14:46:18,908	extract_imdb_data	Finished, Extracted data: ['Hera Pheri', '2000-03-31', 8.1, 67036, 0]
# INFO	2022-10-23 14:46:20,110	extract_imdb_data	Started
# INFO	2022-10-23 14:46:20,235	extract_imdb_data	Finished, Extracted data: ['Unforgiven', '1993-02-19', 8.2, 411123, 4]
# INFO	2022-10-23 14:46:21,178	extract_imdb_data	Started
# INFO	2022-10-23 14:46:21,408	extract_imdb_data	Finished, Extracted data: ['The Treasure of the Sierra Madre', '1948-01-24', 8.2, 125181, 3]
# INFO	2022-10-23 14:46:22,873	extract_imdb_data	Started
# INFO	2022-10-23 14:46:22,996	extract_imdb_data	Finished, Extracted data: ['Aliens', '1988-04-21', 8.4, 713662, 2]
# INFO	2022-10-23 14:46:24,158	extract_imdb_data	Started
# INFO	2022-10-23 14:46:24,288	extract_imdb_data	Finished, Extracted data: ['The Matrix', '1999-08-05', 8.7, 1896696, 4]
# INFO	2022-10-23 14:46:25,261	extract_imdb_data	Started
# INFO	2022-10-23 14:46:25,386	extract_imdb_data	Finished, Extracted data: ['2001: A Space Odyssey', '1979-03-22', 8.3, 665056, 0]
# INFO	2022-10-23 14:46:26,479	extract_imdb_data	Started
# INFO	2022-10-23 14:46:26,744	extract_imdb_data	Finished, Extracted data: ['Mary Poppins', '1986-11-04', 7.8, 172820, 5]
# INFO	2022-10-23 14:46:28,011	extract_imdb_data	Started
# INFO	2022-10-23 14:46:28,147	extract_imdb_data	Finished, Extracted data: ['North by Northwest', '1959-12-18', 8.3, 327261, 0]
# INFO	2022-10-23 14:46:29,532	extract_imdb_data	Started
# INFO	2022-10-23 14:46:29,659	extract_imdb_data	Finished, Extracted data: ['American History X', '1999-04-15', 8.5, 1115546, 0]
# INFO	2022-10-23 14:46:30,932	extract_imdb_data	Started
# INFO	2022-10-23 14:46:31,425	extract_imdb_data	Finished, Extracted data: ['Jagten', '2013-02-21', 8.3, 328174, 0]
# INFO	2022-10-23 14:46:32,440	extract_imdb_data	Started
# INFO	2022-10-23 14:46:32,581	extract_imdb_data	Finished, Extracted data: ['Relatos salvajes', '2014-12-18', 8.1, 197972, 0]
# INFO	2022-10-23 14:46:33,561	extract_imdb_data	Started
# INFO	2022-10-23 14:46:33,808	extract_imdb_data	Finished, Extracted data: ['Jodaeiye Nader az Simin', '2011-08-25', 8.3, 244903, 0]
# INFO	2022-10-23 14:46:34,758	extract_imdb_data	Started

# %%
df.head(5)

# %%
df.sort_values('rating', ascending=False).head(20)

# %%
max_votes = df.sort_values('rating', ascending=False).head(20).max(axis = 0)['votes']

# %%
df['adjusted_rating1'] = df['rating'] + ((max_votes - df['votes']) // 100000  * -0.1)

# %%
df['adjusted_rating2'] =  [oscars_adjustment(x) for x in df['oscars']]

# %%
df['adjusted_rating'] = df['adjusted_rating1'] + df['adjusted_rating2']

# %%
df = df.drop("adjusted_rating1", axis='columns')
df = df.drop("adjusted_rating2", axis='columns')

# %%
sorted_df = df.sort_values('adjusted_rating', ascending=False).head(20).reindex().reset_index(drop=True)
sorted_df.index += 1

# %%
sorted_df

# %%
write_imdb_data_to_csv(p_df=sorted_df, p_file=f'imdb_top_250_adjusted_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv')
